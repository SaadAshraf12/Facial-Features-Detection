# %% [markdown]
# ## MALE DATASET SCRAPIING

# %%
import requests
import os

input_file = "male_data\male_data_links.txt"
output_folder = "male_data"

os.makedirs(output_folder, exist_ok=True)

with open(input_file, 'r') as f:
    urls = [line.strip() for line in f if line.strip()]

for i, url in enumerate(urls):
    try:
        response = requests.get(url, timeout=10)
        if response.status_code == 200:
            ext = url.split('.')[-1].split('?')[0].lower()
            if ext not in ['jpg', 'jpeg', 'png', 'gif', 'webp', 'bmp']:
                ext = 'jpg'
            file_path = os.path.join(output_folder, f"image_{i + 1}.{ext}")
            with open(file_path, 'wb') as f:
                f.write(response.content)
            print(f"[✓] Saved: {file_path}")
        else:
            print(f"[✗] Failed (Status {response.status_code}): {url}")
    except Exception as e:
        print(f"[✗] Error downloading {url}: {e}")
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\Natha\AppData\Local\Temp\ipykernel_27664\582321622.py:4: SyntaxWarning: invalid escape sequence '\m'
#   input_file = "male_data\male_data_links.txt"
# [✓] Saved: male_data\image_1.jpg
# [✓] Saved: male_data\image_2.jpg
# [✓] Saved: male_data\image_3.jpg
# [✓] Saved: male_data\image_4.jpg
# [✓] Saved: male_data\image_5.jpg
# [✓] Saved: male_data\image_6.jpg
# [✓] Saved: male_data\image_7.jpg
# [✓] Saved: male_data\image_8.jpg
# [✓] Saved: male_data\image_9.jpg
# [✓] Saved: male_data\image_10.jpg
# [✓] Saved: male_data\image_11.jpg
# [✓] Saved: male_data\image_12.jpg
# [✓] Saved: male_data\image_13.jpg
# [✓] Saved: male_data\image_14.jpg
# [✓] Saved: male_data\image_15.jpg
# [✓] Saved: male_data\image_16.jpg
# [✓] Saved: male_data\image_17.jpg
# [✓] Saved: male_data\image_18.jpg
# [✓] Saved: male_data\image_19.jpg
# [✓] Saved: male_data\image_20.jpg
# ...

# %% [markdown]
# ## FEMALE DATASET SCRAPIING

# %%
import requests
import os

input_file = r"female_data\female_data_links.txt"
output_folder = "female_data"

os.makedirs(output_folder, exist_ok=True)

with open(input_file, 'r') as f:
    urls = [line.strip() for line in f if line.strip()]

for i, url in enumerate(urls):
    try:
        response = requests.get(url, timeout=10)
        if response.status_code == 200:
            ext = url.split('.')[-1].split('?')[0].lower()
            if ext not in ['jpg', 'jpeg', 'png', 'gif', 'webp', 'bmp']:
                ext = 'jpg'
            file_path = os.path.join(output_folder, f"image_{i + 1}.{ext}")
            with open(file_path, 'wb') as f:
                f.write(response.content)
            print(f"[✓] Saved: {file_path}")
        else:
            print(f"[✗] Failed (Status {response.status_code}): {url}")
    except Exception as e:
        print(f"[✗] Error downloading {url}: {e}")
# Out:
# [✓] Saved: female_data\image_1.jpg
# [✓] Saved: female_data\image_2.jpg
# [✓] Saved: female_data\image_3.jpg
# [✓] Saved: female_data\image_4.jpg
# [✓] Saved: female_data\image_5.jpg
# [✓] Saved: female_data\image_6.jpg
# [✓] Saved: female_data\image_7.jpg
# [✓] Saved: female_data\image_8.jpg
# [✓] Saved: female_data\image_9.jpg
# [✓] Saved: female_data\image_10.jpg
# [✓] Saved: female_data\image_11.jpg
# [✓] Saved: female_data\image_12.jpg
# [✓] Saved: female_data\image_13.jpg
# [✓] Saved: female_data\image_14.jpg
# [✓] Saved: female_data\image_15.jpg
# [✓] Saved: female_data\image_16.jpg
# [✓] Saved: female_data\image_17.jpg
# [✓] Saved: female_data\image_18.jpg
# [✓] Saved: female_data\image_19.jpg
# [✓] Saved: female_data\image_20.jpg
# [✓] Saved: female_data\image_21.jpg
# [✓] Saved: female_data\image_22.jpg
# [✓] Saved: female_data\image_23.jpg
# [✓] Saved: female_data\image_24.jpg
# [✓] Saved: female_data\image_25.jpg
# [✓] Saved: female_data\image_26.jpg
# ...
